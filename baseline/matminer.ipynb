# %%
import random
import os
import shutil
import pandas as pd
from tqdm import tqdm
import csv
import numpy as np
import math
from jarvis.ai.pkgs.utils import regr_scores
from jarvis.db.figshare import data, get_request_data
from jarvis.core.atoms import Atoms
import zipfile
import json
import time
tqdm.pandas()

# %%
def to_unitcell(structure):
    '''
    Make sure coordinates are within the unit cell.
    Used before using structural featurizer.

    Parameters
    ----------
    structure :  pymatgen.core.structure.Structure

    Returns
    -------
    structure :  pymatgen.core.structure.Structure
    '''    
    [site.to_unit_cell(in_place=True) for site in structure.sites]
    return structure
def Featurizer(
        df,
        col_id='structure',
        ignore_errors=True,
        chunksize=20
        ):
    """
    Featurize a dataframe using Matminter featurizers

    Parameters
    ----------
    df : Pandas.DataFrame 
        DataFrame with a column named "structure"

    Returns
    -------
    A DataFrame containing labels as the first columns and features as the rest 

    """
    # For featurization
    from matminer.featurizers.base import MultipleFeaturizer
    from matminer.featurizers.conversions import StrToComposition
    from matminer.featurizers.composition import (ElementProperty, 
                                                  Stoichiometry, 
                                                  ValenceOrbital, 
                                                  IonProperty)
    from matminer.featurizers.structure import (SiteStatsFingerprint, 
                                                StructuralHeterogeneity,
                                                ChemicalOrdering, 
                                                StructureComposition, 
                                                MaximumPackingEfficiency)   
    # Make sure df is a DataFrame
    if isinstance(df, pd.Series):
        df = df.to_frame()   
    # Use composition featurizers if inputs are compositions, otherwise use
    # both composition and structure featurizers
    if col_id != 'structure':
        # convert string to composition 
        a = StrToComposition()
        a._overwrite_data = True
        df[col_id] = a.featurize_dataframe(df,col_id,pbar=False)['composition']
        # no structural features
        struc_feat = []
        # 145 compositional features
        compo_feat = [
            Stoichiometry(),
            ElementProperty.from_preset("magpie"),
            ValenceOrbital(props=['frac']),
            IonProperty(fast=True)
            ]
    else:
        # Ensure sites are within unit cells
        df[col_id] = df[col_id].apply(to_unitcell)
        # 128 structural feature
        struc_feat = [
            SiteStatsFingerprint.from_preset("CoordinationNumber_ward-prb-2017"), 
            SiteStatsFingerprint.from_preset("LocalPropertyDifference_ward-prb-2017"),
            StructuralHeterogeneity(),
            MaximumPackingEfficiency(),
            ChemicalOrdering()
            ]       
        # 145 compositional features
        compo_feat = [
            StructureComposition(Stoichiometry()),
            StructureComposition(ElementProperty.from_preset("magpie")),
            StructureComposition(ValenceOrbital(props=['frac'])),
            StructureComposition(IonProperty(fast=True))
            ]
    # Define the featurizer
    featurizer = MultipleFeaturizer(struc_feat+compo_feat)    
    # Set the chunksize used for Pool.map parallelisation
    featurizer.set_chunksize(chunksize=chunksize)
    X = featurizer.featurize_dataframe(df,col_id,ignore_errors=ignore_errors)  
    # check failed entries    
    failed = np.any(pd.isnull(X.iloc[:,df.shape[1]:]), axis=1)
    if np.sum(failed) > 0:
        print(f'Number failed: {np.sum(failed)}/{len(failed)}')
    print('Featurization completed.')
    return X, failed

# %%
db='dft_3d'
dat = data(db)
n_features = 273
col_id = 'structure'
df = pd.DataFrame(dat)
# Out:
# Obtaining 3D dataset 76k ...
# Reference:https://www.nature.com/articles/s41524-020-00440-1
# Other versions:https://doi.org/10.6084/m9.figshare.6815699
# Loading the zipfile...
# Loading completed.

# %%
df.head()
df_feature = pd.read_csv('X_dft_3d.csv', index_col=0)
df_missing = df[~df.jid.isin(df_feature.jid)]
# Out:
# /tmp/ipykernel_2516773/392227366.py:2: DtypeWarning: Columns (14,17,26,30,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_feature = pd.read_csv('X_dft_3d.csv', index_col=0)

# %%
df_missing["structure"] = df_missing["atoms"].progress_apply(
    lambda x: Atoms.from_dict(x).pymatgen_converter()
)
X_file_all = 'X_dft_3d_all.csv'
X_all, failed = Featurizer(df,col_id=col_id)
X_all.to_csv(X_file_all)
# Out:
# 100%|██████████| 20281/20281 [00:03<00:00, 6386.94it/s]
# /tmp/ipykernel_2516773/2713079394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing["structure"] = df_missing["atoms"].progress_apply(
# /tmp/ipykernel_2516773/4046748637.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_id] = df[col_id].apply(to_unitcell)
# MultipleFeaturizer:   3%|▎         | 680/20281 [00:01<00:26, 731.85it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   5%|▍         | 1000/20281 [00:15<07:14, 44.35it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   6%|▌         | 1147/20281 [00:18<06:44, 47.27it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   6%|▌         | 1243/20281 [00:19<06:14, 50.80it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   7%|▋         | 1355/20281 [00:23<06:56, 45.41it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   7%|▋         | 1387/20281 [00:23<06:37, 47.51it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   7%|▋         | 1412/20281 [00:23<06:08, 51.26it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   7%|▋         | 1448/20281 [00:24<06:28, 48.53it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   7%|▋         | 1463/20281 [00:25<08:23, 37.39it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   7%|▋         | 1500/20281 [00:26<09:13, 33.95it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   7%|▋         | 1520/20281 [00:27<08:05, 38.63it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   8%|▊         | 1540/20281 [00:27<07:25, 42.10it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   8%|▊         | 1560/20281 [00:29<11:23, 27.37it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   8%|▊         | 1580/20281 [00:29<08:52, 35.13it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   8%|▊         | 1600/20281 [00:29<09:42, 32.09it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   9%|▊         | 1740/20281 [00:33<06:41, 46.14it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   9%|▉         | 1800/20281 [00:34<05:51, 52.56it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   9%|▉         | 1820/20281 [00:35<05:32, 55.44it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   9%|▉         | 1840/20281 [00:35<05:22, 57.24it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   9%|▉         | 1900/20281 [00:37<07:03, 43.36it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:   9%|▉         | 1920/20281 [00:37<06:26, 47.45it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  10%|▉         | 1940/20281 [00:38<07:09, 42.72it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  10%|█         | 2080/20281 [00:42<09:07, 33.23it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  11%|█         | 2140/20281 [00:43<06:18, 47.93it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  11%|█         | 2200/20281 [00:45<08:37, 34.95it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  11%|█         | 2220/20281 [00:46<10:15, 29.36it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  11%|█         | 2240/20281 [00:46<08:51, 33.96it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  11%|█         | 2260/20281 [00:49<16:25, 18.29it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  11%|█         | 2280/20281 [00:49<13:45, 21.82it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  11%|█▏        | 2320/20281 [00:52<16:51, 17.76it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  12%|█▏        | 2340/20281 [00:53<13:23, 22.33it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  12%|█▏        | 2360/20281 [00:54<14:08, 21.12it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  12%|█▏        | 2420/20281 [00:55<10:42, 27.80it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:
/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  83%|████████▎ | 16820/20281 [09:48<02:10, 26.60it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  84%|████████▍ | 17100/20281 [09:59<01:49, 28.93it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer:  87%|████████▋ | 17600/20281 [10:16<01:07, 39.77it/s]/scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# MultipleFeaturizer: 100%|██████████| 20281/20281 [12:14<00:00, 27.60it/s]
# Number failed: 1724/20281
# Featurization completed.
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /scratch/yll6162/miniconda3/envs/atomgpt/lib/python3.9/site-packages/pymatgen/core/periodic_table.py:209: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(

# %%
X
# Out:
#                 jid spg_number spg_symbol   formula  formation_energy_peratom  \
# 759      JVASP-1759        194   P6_3/mmc         N                   5.28308
# 20291   JVASP-21212        225      Fm-3m         N                   5.28329
# 34444   JVASP-25167        194   P6_3/mmc        He                   0.00000
# 34574   JVASP-25278        225      Fm-3m        He                   0.00472
# 34610     JVASP-801        229      Im-3m        He                   0.00012
# ...             ...        ...        ...       ...                       ...
# 75988  JVASP-156020        139     I4/mmm  AcRh2Pb2                  -0.30652
# 75989  JVASP-156398        216      F-43m    PrTlZn                  -0.34112
# 75990  JVASP-156099        139     I4/mmm  BaIn2Bi2                  -0.39352
# 75991  JVASP-156007        139     I4/mmm  TmSi2Tc2                  -0.54853
# 75992  JVASP-156008        139     I4/mmm  ThSn2Ru2                  -0.28045
#
#             func  optb88vdw_bandgap  \
# 759    OptB88vdW              2.340
# 20291  OptB88vdW              2.557
# 34444  OptB88vdW             17.733
# 34574  OptB88vdW             17.968
# 34610  OptB88vdW             17.835
# ...          ...                ...
# 75988  OptB88vdW              0.000
# 75989  OptB88vdW              0.000
# 75990  OptB88vdW              0.000
# 75991  OptB88vdW              0.000
# 75992  OptB88vdW              0.000
#
#                                                    atoms slme magmom_oszicar  \
# 759    {'lattice_mat': [[1.8200645909286142, -3.15244...   na            6.0
# 20291  {'lattice_mat': [[5.1420260220398735, -0.0, -0...   na             na
# 34444  {'lattice_mat': [[2.9095085625428467, 3.735584...  0.0            0.0
# 34574  {'lattice_mat': [[2.3721339131314583, -9.69183...  0.0            0.0
# 34610  {'lattice_mat': [[2.6234209456068904, 1.295777...  0.0            0.0
# ...                                                  ...  ...            ...
# 75988  {'lattice_mat': [[-2.374509402119681, 2.374509...   na            0.0
# 75989  {'lattice_mat': [[-0.0, 3.4210598347774503, 3....   na            0.0
# 75990  {'lattice_mat': [[4.082347574975881, -4.076131...   na            0.0
# 75991  {'lattice_mat': [[2.90400678672412, -2.9037689...   na            0.0
# 75992  {'lattice_mat': [[-2.272566257257212, 2.272566...   na            0.0
#
#        ... MagpieData mean SpaceGroupNumber  \
# 759    ...                            194.0
# 20291  ...                            194.0
# 34444  ...                            225.0
# 34574  ...                            225.0
# 34610  ...                            225.0
# ...    ...                              ...
# 75988  ...                            225.0
# 75989  ...                            194.0
# 75990  ...                            106.2
# 75991  ...                            207.2
# 75992  ...                            179.0
#
#       MagpieData avg_dev SpaceGroupNumber MagpieData mode SpaceGroupNumber  \
# 759                                  0.00                            194.0
# 20291                                0.00                            194.0
# 34444                                0.00                            225.0
# 34574                                0.00                            225.0
# 34610                                0.00                            225.0
# ...                                   ...                              ...
# 75988                                0.00                            225.0
# 75989                                0.00                            194.0
# 75990                               75.36                             12.0
# 75991                               15.84                            194.0
# 75992                               30.40                            141.0
#
#       frac s valence electrons frac p valence electrons  \
# 759                   0.400000                 0.600000
# 20291                 0.400000                 0.600000
# 34444                 1.000000                 0.000000
# 34574                 1.000000                 0.000000
# 34610                 1.000000                 0.000000
# ...                        ...                      ...
# 75988                 0.103896                 0.051948
# 75989                 0.136364                 0.022727
# 75990                 0.116279                 0.093023
# 75991                 0.270270                 0.108108
# 75992                 0.166667                 0.083333
#
#       frac d valence electrons frac f valence electrons  compound possible  \
# 759                   0.000000                 0.000000               True
# 20291                 0.000000                 0.000000               True
# 34444                 0.000000                 0.000000               True
# 34574                 0.000000                 0.000000               True
# 34610                 0.000000                 0.000000               True
# ...                        ...                      ...                ...
# 75988                 0.480519                 0.363636              False
# 75989                 0.454545                 0.386364              False
# 75990                 0.465116                 0.325581              False
# 75991                 0.270270                 0.351351              False
# 75992                 0.750000                 0.000000              False
#
#       max ionic char avg ionic char
# 759         0.000000       0.000000
# 20291       0.000000       0.000000
# 34444       0.000000       0.000000
# 34574       0.000000       0.000000
# 34610       0.000000       0.000000
# ...              ...            ...
# 75988       0.314924       0.048812
# 75989       0.065366       0.013761
# 75990       0.273288       0.038523
# 75991       0.100238       0.016038
# 75992       0.183314       0.025207
#
# [20281 rows x 338 columns]

# %%
col_list =  [col for col in X.columns if col not in df_feature.columns]
col_list
# Out:
# ['Tc_supercon']

# %%
pd.read_csv('X_dft_3d_all.csv', index_col=0)
# Out:
# /tmp/ipykernel_2644904/2171302545.py:1: DtypeWarning: Columns (10,14,17,26,30,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('X_dft_3d_all.csv', index_col=0)
#                 jid  spg_number spg_symbol   formula  \
# 0       JVASP-90856         129     P4/nmm  TiCuSiAs
# 1       JVASP-86097         221      Pm-3m      DyB6
# 2       JVASP-64906         119      I-4m2   Be2OsRu
# 3       JVASP-98225          14     P2_1/c       KBi
# 4          JVASP-10         164      P-3m1      VSe2
# ...             ...         ...        ...       ...
# 75988  JVASP-156020         139     I4/mmm  AcRh2Pb2
# 75989  JVASP-156398         216      F-43m    PrTlZn
# 75990  JVASP-156099         139     I4/mmm  BaIn2Bi2
# 75991  JVASP-156007         139     I4/mmm  TmSi2Tc2
# 75992  JVASP-156008         139     I4/mmm  ThSn2Ru2
#
#        formation_energy_peratom       func  optb88vdw_bandgap  \
# 0                      -0.42762  OptB88vdW              0.000
# 1                      -0.41596  OptB88vdW              0.000
# 2                       0.04847  OptB88vdW              0.000
# 3                      -0.44140  OptB88vdW              0.472
# 4                      -0.71026  OptB88vdW              0.000
# ...                         ...        ...                ...
# 75988                  -0.30652  OptB88vdW              0.000
# 75989                  -0.34112  OptB88vdW              0.000
# 75990                  -0.39352  OptB88vdW              0.000
# 75991                  -0.54853  OptB88vdW              0.000
# 75992                  -0.28045  OptB88vdW              0.000
#
#                                                    atoms slme magmom_oszicar  \
# 0      {'lattice_mat': [[3.566933224304235, 0.0, -0.0...   na            0.0
# 1      {'lattice_mat': [[4.089078911208881, 0.0, 0.0]...   na            0.0
# 2      {'lattice_mat': [[-1.833590720595598, 1.833590...   na            0.0
# 3      {'lattice_mat': [[7.2963518353359165, 0.0, 0.0...   na            0.0
# 4      {'lattice_mat': [[1.6777483798834445, -2.90594...   na            0.0
# ...                                                  ...  ...            ...
# 75988  {'lattice_mat': [[-2.374509402119681, 2.374509...   na            0.0
# 75989  {'lattice_mat': [[-0.0, 3.4210598347774503, 3....   na            0.0
# 75990  {'lattice_mat': [[4.082347574975881, -4.076131...   na            0.0
# 75991  {'lattice_mat': [[2.90400678672412, -2.9037689...   na            0.0
# 75992  {'lattice_mat': [[-2.272566257257212, 2.272566...   na            0.0
#
#        ... MagpieData mean SpaceGroupNumber  \
# 0      ...                       203.000000
# 1      ...                       170.000000
# 2      ...                       194.000000
# 3      ...                       120.500000
# 4      ...                        85.666667
# ...    ...                              ...
# 75988  ...                       225.000000
# 75989  ...                       194.000000
# 75990  ...                       106.200000
# 75991  ...                       207.200000
# 75992  ...                       179.000000
#
#       MagpieData avg_dev SpaceGroupNumber MagpieData mode SpaceGroupNumber  \
# 0                               23.000000                            166.0
# 1                                6.857143                            166.0
# 2                                0.000000                            194.0
# 3                              108.500000                             12.0
# 4                               95.555556                             14.0
# ...                                   ...                              ...
# 75988                            0.000000                            225.0
# 75989                            0.000000                            194.0
# 75990                           75.360000                             12.0
# 75991                           15.840000                            194.0
# 75992                           30.400000                            141.0
#
#       frac s valence electrons frac p valence electrons  \
# 0                     0.205882                 0.147059
# 1                     0.466667                 0.200000
# 2                     0.205882                 0.000000
# 3                     0.100000                 0.100000
# 4                     0.162162                 0.216216
# ...                        ...                      ...
# 75988                 0.103896                 0.051948
# 75989                 0.136364                 0.022727
# 75990                 0.116279                 0.093023
# 75991                 0.270270                 0.108108
# 75992                 0.166667                 0.083333
#
#       frac d valence electrons frac f valence electrons  compound possible  \
# 0                     0.647059                 0.000000              False
# 1                     0.000000                 0.333333              False
# 2                     0.382353                 0.411765              False
# 3                     0.333333                 0.466667              False
# 4                     0.621622                 0.000000              False
# ...                        ...                      ...                ...
# 75988                 0.480519                 0.363636              False
# 75989                 0.454545                 0.386364              False
# 75990                 0.465116                 0.325581              False
# 75991                 0.270270                 0.351351              False
# 75992                 0.750000                 0.000000              False
#
#       max ionic char avg ionic char
# 0           0.097332       0.012494
# 1           0.154731       0.018947
# 2           0.094461       0.023615
# 3           0.302324       0.075581
# 4           0.190712       0.042380
# ...              ...            ...
# 75988       0.314924       0.048812
# 75989       0.065366       0.013761
# 75990       0.273288       0.038523
# 75991       0.100238       0.016038
# 75992       0.183314       0.025207
#
# [75993 rows x 338 columns]
